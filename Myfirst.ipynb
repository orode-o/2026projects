# %% [markdown]
# <a href="https://colab.research.google.com/github/orode-o/2026projects/blob/main/Myfirst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Orode's learning

print ("Hello world")

#Data Types = string, char, bool, int, float

orodesvar = int(5)
print (orodesvar)
# Out:
# Hello world
# 5

# %%
orodesstring = str("My name is Orode")
print (orodesstring)
# Out:
# My name is Orode

# %%
orodesvar2 = str('qwertyuiopu67676skibidi')
print (orodesvar2)
# Out:
# qwertyuiopu67676skibidi

# %%
ofeghasvar = orodesvar
print (ofeghasvar)
# Out:
# 5

# %%
#Addition  +
#Subtraction  -
#Division /
#Multiplication *
#Assignement  =
#Not Equals to !=
# Comparatively  ==

print (33+34)
print (100-33)
print (67/1)
print (1*67)
# Out:
# 67
# 67
# 67.0
# 67

# %%
a = int(input("Enter a value "))
b = int(input("Enter b value "))

addition = a + b
print (addition)
# Out:
# Enter a value 33
# Enter b value 34
# 67

# %%
subtraction = a - b
multiplication = a * b
division = a / b
print (subtraction)
print (multiplication)
print (division)

print (subtraction, multiplication, division)
# Out:
# -1
# 1122
# 0.9705882352941176
# -1 1122 0.9705882352941176
